# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('creditcard.csv')

# %%
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
data = df.drop(['Time'],axis=1)

# %%
data.head(3)
# Out:
#          V1        V2        V3        V4        V5        V6        V7  \
# 0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
#
#          V8        V9       V10  ...       V21       V22       V23       V24  \
# 0  0.098698  0.363787  0.090794  ... -0.018307  0.277838 -0.110474  0.066928
# 1  0.085102 -0.255425 -0.166974  ... -0.225775 -0.638672  0.101288 -0.339846
# 2  0.247676 -1.514654  0.207643  ...  0.247998  0.771679  0.909412 -0.689281
#
#         V25       V26       V27       V28  Amount  Class
# 0  0.128539 -0.189115  0.133558 -0.021053  149.62      0
# 1  0.167170  0.125895 -0.008983  0.014724    2.69      0
# 2 -0.327642 -0.139097 -0.055353 -0.059752  378.66      0
#
# [3 rows x 30 columns]

# %%
for i in columns[0:-2]:
    data[i] = data[i]**100

# %%
columns = list(data.columns)

# %%
columns[0:-2]
# Out:
# ['V1',
#  'V2',
#  'V3',
#  'V4',
#  'V5',
#  'V6',
#  'V7',
#  'V8',
#  'V9',
#  'V10',
#  'V11',
#  'V12',
#  'V13',
#  'V14',
#  'V15',
#  'V16',
#  'V17',
#  'V18',
#  'V19',
#  'V20',
#  'V21',
#  'V22',
#  'V23',
#  'V24',
#  'V25',
#  'V26',
#  'V27',
#  'V28']

# %%
import math

# %%
math.sqrt(1.5)
# Out:
# 1.224744871391589

# %%
g = pd.Series(range(-10,10))

# %%
data.head()
# Out:
#              V1             V2            V3            V4             V5  \
# 0  2.227058e+13  1.591861e-114  7.623009e-04  8.507728e+13   8.567735e-48
# 1  4.191980e+07   3.256591e-58  2.265208e+25  1.389106e-35  6.728188e-123
# 2  2.001237e+13   5.197144e+12  6.304136e-25  8.977646e-43   1.492458e-30
# 3  3.235389e-02   5.891104e-74  4.293801e-24  4.127957e-07  2.094820e-199
# 4  2.396608e+06   2.169844e-06  1.231963e-36  3.421065e-40   9.551478e-40
#
#               V6             V7             V8            V9            V10  \
# 0   3.166902e-34   8.880129e-63  2.696446e-101  1.215385e-44  6.394362e-105
# 1  3.733020e-109  4.510928e-111  9.858267e-108  5.325520e-60   1.840741e-78
# 2   3.461765e+25   6.965456e-11   2.445429e-61  1.074862e+18   5.391397e-69
# 3   3.923923e+09   3.857249e-63   4.834123e-43  1.615844e+14  9.960682e-127
# 4  1.554459e-102   2.000458e-23   1.667144e-57  1.825944e-09   4.828256e-13
#
# ...

# %%
math.sqrt(-2.312227)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-65-5766ed5dee08> in <module>
# ----> 1 math.sqrt(-2.312227)
#
# ValueError: math domain error

# %%
data.isnull().sum()
# Out:
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
data.shape
# Out:
# (284807, 30)

# %%
df.isnull().sum()
# Out:
# Time           0
# V1             0
# V2             0
# V3        128163
# V4             0
# V5             0
# V6             0
# V7             0
# V8             0
# V9             0
# V10            0
# V11            0
# V12            0
# V13            0
# V14            0
# V15            0
# V16            0
# V17            0
# V18            0
# V19            0
# V20            0
# V21            0
# V22            0
# V23            0
# V24            0
# V25            0
# V26            0
# V27            0
# V28            0
# Amount         0
# Class          0
# dtype: int64

# %%
data.head()
# Out:
#          V1        V2        V3        V4        V5        V6        V7  \
# 0  1.849075  0.005297  0.866249  1.899312  0.114461  0.213802  0.057407
# 1  1.420523  0.070836  3.214417  0.200842  0.003602  0.006783  0.006210
# 2  1.845126  1.796037  0.328090  0.144233  0.253208  3.241798  0.626410
# 3  0.933681  0.034309  0.340923  0.745272  0.000106  1.555516  0.056458
# 4  1.341504  0.770422  0.191343  0.162436  0.165806  0.009201  0.351579
#
#          V8        V9       V10  ...       V21       V22       V23       V24  \
# 0  0.009741  0.132341  0.008244  ...  0.000335  0.077194  0.012204  0.004479
# 1  0.007242  0.065242  0.027880  ...  0.050974  0.407902  0.010259  0.115496
# 2  0.061343  2.294178  0.043116  ...  0.061503  0.595489  0.827031  0.475108
# 3  0.142458  1.923836  0.003020  ...  0.011729  0.000028  0.036222  1.381977
# 4  0.073188  0.668698  0.567121  ...  0.000089  0.637249  0.018895  0.019956
#
#         V25       V26       V27       V28  Amount  Class
# ...

# %%
data['V1'].plot(kind='hist')

# %%
x = data.drop(['Class'],axis=1)
y = data['Class']

# %%
from sklearn.ensemble import RandomForestClassifier

tand = RandomForestClassifier()

from sklearn.model_selection import train_test_split

x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.5,random_state=100)

# %%
tand.fit(x_train,y_train)
# Out:
# C:\Users\acer\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#                        max_depth=None, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=10,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)

# %%
predict = tand.predict(x_test)

# %%
from sklearn.metrics import classification_report,recall_score,f1_score,confusion_matrix

# %%
print(classification_report(y_test,predict))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00    142153
#            1       0.90      0.75      0.81       251
#
#     accuracy                           1.00    142404
#    macro avg       0.95      0.87      0.91    142404
# weighted avg       1.00      1.00      1.00    142404

# %%
print(confusion_matrix(y_test,predict))
# Out:
# [[142132     21]
#  [    64    187]]
